# %%
# 판다스 라이브러리 불러오기
import pandas as pd
file_path = 'C:\\data\\bicycle.csv'

df1 = pd.read_csv(file_path,engine='python',encoding='cp949')
print(df1)
# Out:
#             자전거번호                 대여일시  대여 대여소번호            대여 대여소명  대여거치대  \
# 0       SPB-23220  2019-11-01 08:48:31       646  장한평역 1번출구 (국민은행앞)      3
# 1       SPB-16216  2019-11-04 08:38:39       646  장한평역 1번출구 (국민은행앞)      2
# 2       SPB-21097  2019-11-04 08:46:37       646  장한평역 1번출구 (국민은행앞)      1
# 3       SPB-22292  2019-11-05 08:34:59       646  장한평역 1번출구 (국민은행앞)      1
# 4       SPB-07935  2019-11-05 12:29:00       512        뚝섬역 1번 출구 옆     11
# ...           ...                  ...       ...                ...    ...
# 799995  SPB-22201  2019-11-28 22:26:11      1203          밀리아나2빌딩 앞     19
# 799996  SPB-22290  2019-11-28 22:29:02      1230           송파중학교 정문      9
# 799997  SPB-15270  2019-11-28 22:16:45      2622        올림픽공원역 3번출구      7
# 799998  SPB-11405  2019-11-28 22:33:25      1050         둔촌역 3번 출입구     14
# 799999  SPB-13801  2019-11-28 22:51:31      1288           문정중교 사거리      8
#
#                        반납일시  반납대여소번호     반납대여소명  반납거치대  이용시간    이용거리
# ...
